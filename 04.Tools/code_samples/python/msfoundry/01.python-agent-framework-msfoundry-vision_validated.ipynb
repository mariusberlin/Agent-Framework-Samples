# %%
# ! pip install -r ../../../../requirements.txt -U

# %%
from agent_framework import Message, Content

from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity.aio import AzureCliCredential

# %%
import os
import base64
from dotenv import load_dotenv

# %%
load_dotenv("../../../../.env")
# Out:
# True

# %%
AgentName = "Vision-Agent"
AgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion"

# %%
async with (
    AzureCliCredential() as credential,
    AzureAIProjectAgentProvider(project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"], credential=credential) as client,
):
    agent = await client.create_agent(
        model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
        instructions=AgentInstructions,
        name=AgentName
    )

    image_path = "../../files/home.png"
    with open(image_path, "rb") as image_file:
        image_b64 = base64.b64encode(image_file.read()).decode()
    image_uri = f"data:image/png;base64,{image_b64}"
    message = Message(
        role="user",
        contents=[
            Content.from_text(text="Please find the relevant furniture according to the image and give the corresponding price for each piece of furniture"),
            Content.from_uri(uri=image_uri, media_type="image/png"),
        ]
    )
    first_result = await agent.run(message)

    print(f"Agent: {first_result.text}")
# Out:
# Agent: Here’s a breakdown of the main furniture items visible in the room, with realistic mid‑range retail price estimates (USD). Actual prices will vary by brand/store, but this gives you a buying guide:
#
# 1. **3‑Seat Modern Sofa (white, with cushions)**
#    - Style: Straight‑arm, fabric, modern minimalist
#    - Estimated price: **$700–$1,000** (sofa only; cushions often included or +$80–$150 if separate)
#
# 2. **Accent Armchair (dark blue lounge chair by the window)**
#    - Style: High back, upholstered lounge chair
#    - Estimated price: **$250–$450**
#
# 3. **Coffee Table (oval, light wood top, tapered legs)**
#    - Style: Mid‑century modern, wood veneer or solid wood
#    - Estimated price: **$180–$350**
#
# 4. **TV Stand / Media Console (long, light‑wood cabinet under TV)**
#    - Style: Low, minimalist with drawers and open shelves
#    - Estimated price: **$300–$600**
#
# 5. **Side Table – Left (round top, slim metal tripod legs near chair)**
#    - Style: Small accent table
#    - Estimated price: **$80–$150**
#
# 6. **Side Table – Right (rectangular table beside sofa with lamp)**
#    - Style: Metal frame with light‑colored top
#    - Estimated price: **$100–$200**
#
# 7. **Ceiling Chandelier (black frame with globe bulbs)**
#    - Style: Modern/industrial multi‑arm chandelier
#    - Estimated price: **$200–$400**
#
# 8. **Pendant Lights (two glass globe pendants near left wall)**
#    - Style: Hanging glass orbs
#    - Estimated price: **$70–$140 each** (≈ **$140–$280** for both)
#
# 9. **Table Lamp (on right side table)**
#    - Style: Small fabric shade, simple base
#    - Estimated price: **$60–$120**
#
# 10. **Curtains & Sheers (floor‑to‑ceiling on back window and side)**
#     - Includes tracks/rods, blackout panels + white sheers
#     - Estimated price: **$250–$500** (for full window wall)
#
# 11. **Wall Art / Framed Print (deer picture above sofa)**
#     - Style: Framed poster/print
#     - Estimated price: **$60–$150**
#
# 12. **Throw Pillows (blue/white decorative cushions on sofa)**
#     - Estimated price: **$20–$40 each** (≈ 6–7 pieces → **$120–$280** total)
#
# 13. **Decor on Coffee Table & TV Stand (tray, vases, books, small sculptures)**
#     - Mixed accessories
#     - Estimated price: **$100–$250** total
#
# If you’d like, I can turn this into a shopping list with links from a specific retailer (e.g., IKEA, West Elm, Amazon) and match each piece more closely to that store’s products and exact prices.
